# %% [markdown]
# 1+2

# %% [markdown]
# # Omregning fra C til F

# %%
C = 100 # [grader C]
F = C*1.8 + 32 # [grader f]
print(F)
# Out:
# 212.0

# %% [markdown]
# ![250px-Headshot_of_Anders_Celsius.jpg](attachment:250px-Headshot_of_Anders_Celsius.jpg)
